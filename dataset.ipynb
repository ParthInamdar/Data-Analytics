# %%
import pandas as pd

df = pd.read_csv("Amazon.csv")

# %%
import pandas as pd

df = pd.read_csv("Amazon.csv")

india_df = df[df["Country"] == "India"]

print(india_df)
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0      ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 3      ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 7      ORD0000008  2022-11-10  CUST031165    Rohit Kumar    P00028
# 31     ORD0000032  2023-03-30  CUST044089   Sunita Gupta    P00006
# 42     ORD0000043  2024-09-01  CUST020850   Sneha Sharma    P00031
# ...           ...         ...         ...            ...       ...
# 99976  ORD0099977  2020-10-22  CUST005955    Rohit Reddy    P00015
# 99979  ORD0099980  2020-06-02  CUST036959   Arjun Kapoor    P00023
# 99985  ORD0099986  2023-10-31  CUST005338   Sahil Kapoor    P00050
# 99994  ORD0099995  2022-01-09  CUST028035   Kabir Kapoor    P00011
# 99995  ORD0099996  2023-03-07  CUST001356    Karan Joshi    P00047
#
#              ProductName           Category      Brand  Quantity  UnitPrice  \
# 0             Drone Mini              Books  BrightLux         3     106.59
# ...

# %%
df.drop("CustomerName", axis=1)
# Out:
#           OrderID   OrderDate  CustomerID ProductID          ProductName  \
# 0      ORD0000001  2023-01-31  CUST001504    P00014           Drone Mini
# 1      ORD0000002  2023-12-30  CUST000178    P00040           Microphone
# 2      ORD0000003  2022-05-10  CUST047516    P00044  Power Bank 20000mAh
# 3      ORD0000004  2023-07-18  CUST030059    P00041       Webcam Full HD
# 4      ORD0000005  2023-02-04  CUST048677    P00029              T-Shirt
# ...           ...         ...         ...       ...                  ...
# 99995  ORD0099996  2023-03-07  CUST001356    P00047    Memory Card 128GB
# 99996  ORD0099997  2021-11-24  CUST031254    P00046          Car Charger
# 99997  ORD0099998  2023-04-29  CUST012579    P00030          Dress Shirt
# 99998  ORD0099999  2021-11-01  CUST026243    P00046          Car Charger
# 99999  ORD0100000  2021-12-04  CUST029492    P00019        LED Desk Lamp
#
#                 Category       Brand  Quantity  UnitPrice  Discount     Tax  \
# ...

# %%
df[df["ProductName"] == "jeans"]
print(df[df["ProductName"] == "jeans"])
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0      ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1      ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2      ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3      ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4      ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
# ...           ...         ...         ...            ...       ...
# 99995  ORD0099996  2023-03-07  CUST001356    Karan Joshi    P00047
# 99996  ORD0099997  2021-11-24  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  2023-04-29  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  2021-11-01  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  2021-12-04  CUST029492   Sunita Reddy    P00019
#
#                ProductName           Category       Brand  Quantity  \
# 0               Drone Mini              Books   BrightLux         3
# ...
